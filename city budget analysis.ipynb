# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read data
dt = pd.read_csv('budget_allocation_opinion.csv')

# %%
dt.columns
# Out:
# Index(['Timestamp', 'Name', 'City you live in', 'aware', 'favored_sector',
#        'unfavored_sector', 'workforce_group', 'tax_significance_score',
#        'lower_taxes'],
#       dtype='object')

# %%
dt['favored_sector'].value_counts()
# Out:
# health               9
# education            8
# green initiatives    1
# infrastructure       1
# Name: favored_sector, dtype: int64

# %%
fav_sector = dt['favored_sector'].value_counts()
plt.title("favored sectors", fontsize=14)
plt.pie(fav_sector,labels=['health','education','green initiatives','infrastructure'],autopct='%1.1f%%',startangle=90)
plt.show()

# %%
dt['unfavored_sector'].value_counts()
# Out:
# security                  9
# green initiatives         6
# infrastructure            2
# universal basic income    2
# Name: unfavored_sector, dtype: int64

# %%
unfav_sector = dt['unfavored_sector'].value_counts()
plt.title("unfavored sectors", fontsize=14)
plt.pie(unfav_sector,labels=['security','green initiatives','infrastructure','universal basic income'],autopct='%1.1f%%',startangle=90)
plt.show()

# %%
workforce = dt['workforce_group'].value_counts()

# %%
plt.title('workforce_group', fontsize=14)
plt.pie(workforce,labels=['young professional','unemployed','working adult','student'],autopct='%1.1f%%',startangle=90)
plt.show()

# %%
workforce.plot.barh()
# Out:
# <AxesSubplot:>
